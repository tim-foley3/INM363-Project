# %%
import gym
import random, math
import numpy as np
import arcade
from skimage import data, color
from skimage.transform import rescale, resize, downscale_local_mean
from PIL import Image

        
from LightEnvCopy import LightEnv

import gym.spaces
from gym.spaces import Discrete, Box

from ray.rllib.env.env_context import EnvContext
from ray.rllib.models import ModelCatalog

from collections import namedtuple

# Do the math to figure out our screen dimensions
SCREEN_WIDTH = 800
SCREEN_HEIGHT = 600
SCREEN_TITLE = "Game 1: Let There Be Light!"

# COnvenient data structure to hold information about actions
Action = namedtuple('Action', 'name index delta_i delta_j')

up = Action('up', 0, -1, 0)    
down = Action('down', 1, 1, 0)    
left = Action('left', 2, 0, -1)    
right = Action('right', 3, 0, 1)    

index_to_actions = {}
for action in [up, down, left, right]:
    index_to_actions[action.index] = action
# print(index_to_actions[0].name)
str_to_actions = {}
for action in [up, down, left, right]:
    str_to_actions[action.name] = action
#TF End - Adding in actions for action conversion


class LightEnvWrapper(gym.Env, LightEnv):
    """Class that wraps the Lights Environment to make it 
    compatible with RLLib."""

    metadata = {"render.modes": ["rgb_array", "state_pixels"]}
    
    def __init__(self, config: EnvContext):
        super().__init__(SCREEN_WIDTH, SCREEN_HEIGHT, SCREEN_TITLE)
        self.torch_collected = False
        self.torch_collected_count = []
        self.mygame = LightEnv
        self.steps_taken = 0
        #The action space is a choice of 4 actions: U/D/L/R.
        self.action_space = Discrete(4)
        
        #The observation space is a fixed image of the current game screen
        self.observation_space = Box(low=0, high=255, shape=(84,84, 4), dtype=np.uint8)
        
    def reset(self):
        print("resetting in wrapper")
        
        if self.torch_collected == 1:
            print("Torch was collected this episode!")
        else:
            print("Torch was not collected this episode...")
        self.torch_collected_count.append(self.torch_collected)
        print(self.torch_collected_count)

        self.render(self)
        #Resets the state of the environment for a new episode and an initial observation.
        obs_mygame = self.mygame.reset(self)
        
        #Open up the resetted image to verify working correctly.
        obs_mygame.show()
        
        self.mygame.on_draw(self)
        #Convert observation to 84x84 resolution and np array for rllib.
        obs = self.convert_observations(obs_mygame)
        
        self.steps_taken = 0
        return obs

    def step(self, action):
        self.steps_taken += 1
        
        #Making sure an action is chosen, either: 0, 1, 2, 3.
        assert action in [0, 1, 2, 3] #0-up,1-down,2-left,3-right.
        
        #Convert the numeric action to a keyword: up, down, left, right.
        actions_myenv = index_to_actions[action].name #returns a word, one of: up/down/left/right
#         print(f"action taken: {actions_myenv}")
        
        #Update the window with on_update()
        self.render(self)
#         print("env rendered")
        #Compute observation extracted from the window (800x600), with reward and done flag.
        obs, reward, done, torch_collected, fps_check = self.mygame.step(self,actions_myenv)
        if torch_collected == True:
            self.torch_collected = 1
        else:
            self.torch_collected = 0
                    
        if self.steps_taken % 100 == 0: #33 steps roughly equates to 1 second in game time
            print(f"total score is {self.score} at time: {self.mygame.time_taken_reported(self)}")
            print(f"FPS is currently: {fps_check}")
        #Convert observation to 84x84 resolution and np array for rllib.
        obs_mygame = self.convert_observations(obs)
        
        #If the reward has been obtained, reset the environment and start again
        if done == True:
            print(f"done is {done}, resetting environment in wrapper.")
            print(f"steps taken: {self.steps_taken}")
            obs.show()
            self.reset()
        
        return obs_mygame, reward, done, {}

    def seed(self, seed=None):
        random.seed(seed)

    def convert_observations(self, obs_mygame): #resizing and converting to array for rllib processing
        # We normalize and concatenate observations
        obs = obs_mygame
        obs_resized = obs.resize((84,84))
        obsarray = np.array(obs_resized)
        return obsarray
    
    def render(self, mode='state_pixels'):
#         self.mygame.update(self)
        self.mygame.on_draw(self)
        test = self.mygame.time_taken_reported(self)
# Out:
# C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\tensorflow_probability\python\__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if (distutils.version.LooseVersion(tf.__version__) <

# %% [markdown]
# ### Now run the rllib script to train the agent

# %% [markdown]
# ### Manual Grid Search

# %% [markdown]
# #### lr

# %%
import gym
import ray.rllib.agents.ppo.ppo as ppo
from ray.rllib.algorithms.ppo import PPOConfig
from ray import air
from ray import tune
import os


config = PPOConfig()


from ray.rllib.algorithms.ppo import PPOConfig
RAY_DISABLE_MEMORY_MONITOR = 1
config = PPOConfig().training(gamma=0.99, lr=0.001, kl_coeff=0.2, entropy_coeff=1,
#                               entropy_coeff_schedule=[[0,1],[1000,0]],
                             sgd_minibatch_size=128, num_sgd_iter=60)\
            .resources(num_gpus=0)\
            .rollouts(num_envs_per_worker=1, num_rollout_workers=2, recreate_failed_workers=True, horizon=30000)
config.normalize_actions=False
config.env=LightEnvWrapper
config.clip_actions=False
print(config.to_dict())
# Build a Algorithm object from the config
trainer = ppo.PPOTrainer(config=config)

avg_rewards = []
num_iterations = []
for episode in range(100):
    print("Starting episode ", episode)
    # Perform one iteration of training the policy with PPO
    result = trainer.train()
    #print(pretty_print(result))
    print("episode reward mean: ", result['episode_reward_mean'])
    avg_rewards.append(result['episode_reward_mean'])
    num_iterations.append(episode)
    if episode % 10 == 0:
        checkpoint = trainer.save()
        print("checkpoint saved at", checkpoint)
    print("End of episode ", episode)
# Out:
# {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'num_gpus': 0, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, '_fake_gpus': False, 'custom_resources_per_worker': {}, 'placement_strategy': 'PACK', 'eager_tracing': False, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'env': <class '__main__.LightEnvWrapper'>, 'env_config': {}, 'observation_space': None, 'action_space': None, 'env_task_fn': None, 'render_env': False, 'clip_rewards': None, 'normalize_actions': False, 'clip_actions': False, 'disable_env_checking': False, 'num_workers': 2, 'num_envs_per_worker': 1, 'sample_collector': <class 'ray.rllib.evaluation.collectors.simple_list_collector.SimpleListCollector'>, 'sample_async': False, 'enable_connectors': False, 'rollout_fragment_length': 200, 'batch_mode': 'truncate_episodes', 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'validate_workers_after_construction': True, 'ignore_worker_failures': False, 'recreate_failed_workers': True, 'restart_failed_sub_environments': False, 'num_consecutive_worker_failures_tolerance': 100, 'horizon': 30000, 'soft_horizon': False, 'no_done_at_end': False, 'preprocessor_pref': 'deepmind', 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'compress_observations': False, 'enable_tf1_exec_eagerly': False, 'sampler_perf_stats_ema_coef': None, 'gamma': 0.9, 'lr': 0.001, 'train_batch_size': 4000, 'model': {'_use_default_native_models': False, '_disable_preprocessor_api': False, '_disable_action_flattening': False, 'fcnet_hiddens': [256, 256], 'fcnet_activation': 'tanh', 'conv_filters': None, 'conv_activation': 'relu', 'post_fcnet_hiddens': [], 'post_fcnet_activation': 'relu', 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': False, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action': False, 'lstm_use_prev_reward': False, '_time_major': False, 'use_attention': False, 'attention_num_transformer_units': 1, 'attention_dim': 64, 'attention_num_heads': 1, 'attention_head_dim': 32, 'attention_memory_inference': 50, 'attention_memory_training': 50, 'attention_position_wise_mlp_dim': 32, 'attention_init_gru_gate_bias': 2.0, 'attention_use_n_prev_actions': 0, 'attention_use_n_prev_rewards': 0, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_model_config': {}, 'custom_action_dist': None, 'custom_preprocessor': None, 'lstm_use_prev_action_reward': -1}, 'optimizer': {}, 'explore': True, 'exploration_config': {'type': 'StochasticSampling'}, 'input_config': {}, 'actions_in_input_normalized': False, 'postprocess_inputs': False, 'shuffle_buffer_size': 0, 'output': None, 'output_config': {}, 'output_compress_columns': ['obs', 'new_obs'], 'output_max_file_size': 67108864, 'evaluation_interval': None, 'evaluation_duration': 10, 'evaluation_duration_unit': 'episodes', 'evaluation_sample_timeout_s': 180.0, 'evaluation_parallel_to_training': False, 'evaluation_config': {}, 'off_policy_estimation_methods': {}, 'evaluation_num_workers': 0, 'always_attach_evaluation_results': False, 'in_evaluation': False, 'sync_filters_on_rollout_workers_timeout_s': 60.0, 'keep_per_episode_custom_metrics': False, 'metrics_episode_collection_timeout_s': 60.0, 'metrics_num_episodes_for_smoothing': 100, 'min_time_s_per_iteration': None, 'min_train_timesteps_per_iteration': 0, 'min_sample_timesteps_per_iteration': 0, 'logger_creator': None, 'logger_config': None, 'log_level': 'WARN', 'log_sys_usage': True, 'fake_sampler': False, 'seed': None, '_tf_policy_handles_more_than_one_loss': False, '_disable_preprocessor_api': False, '_disable_action_flattening': False, '_disable_execution_plan_api': T ...
# C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\ray_option_utils.py:266: DeprecationWarning: Setting 'object_store_memory' for actors is deprecated since it doesn't actually reserve the required object store memory. Use object spilling that's enabled by default (https://docs.ray.io/en/releases-2.0.0/ray-core/objects/object-spilling.html) instead to bypass the object store memory size limitation.
#   warnings.warn(
# 2022-09-27 21:46:37,332	INFO worker.py:1518 -- Started a local Ray instance.
# (pid=21952) Windows fatal exception: code 0xc0000139
# (pid=21952)
# (pid=5152) Windows fatal exception: code 0xc0000139
# (pid=5152)
# (pid=21952) C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\tensorflow_probability\python\__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=21952)   if (distutils.version.LooseVersion(tf.__version__) <
# (pid=5152) C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\tensorflow_probability\python\__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=5152)   if (distutils.version.LooseVersion(tf.__version__) <
# (RolloutWorker pid=21952) 2022-09-27 21:46:56,038	WARNING env.py:142 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=21952) resetting in wrapper
# (RolloutWorker pid=21952) Torch was not collected this episode...
# (RolloutWorker pid=21952) [False]
# (RolloutWorker pid=5152) resetting in wrapper
# (RolloutWorker pid=5152) Torch was not collected this episode...
# (RolloutWorker pid=5152) [False]
# (RolloutWorker pid=21952) resetting
# (RolloutWorker pid=5152) resetting
# 2022-09-27 21:47:01,755	INFO trainable.py:160 -- Trainable.setup took 29.034 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2022-09-27 21:47:01,758	WARNING util.py:65 -- Install gputil for GPU system monitoring.
# Starting episode  0
# (RolloutWorker pid=21952) resetting in wrapper
# (RolloutWorker pid=21952) Torch was not collected this episode...
# (RolloutWorker pid=21952) [False, 0]
# (RolloutWorker pid=21952) resetting
# (RolloutWorker pid=5152) resetting in wrapper
# (RolloutWorker pid=5152) Torch was not collected this episode...
# (RolloutWorker pid=5152) [False, 0]
# (RolloutWorker pid=5152) resetting
# (RolloutWorker pid=5152) total score is -4 at time: 2
# (RolloutWorker pid=5152) FPS is currently: 88
# (RolloutWorker pid=21952) total score is -4 at time: 2
# (RolloutWorker pid=21952) FPS is currently: 80
# (RolloutWorker pid=5152) total score is -5 at time: 3
# (RolloutWorker pid=5152) FPS is currently: 93
# (RolloutWorker pid=21952) total score is -5 at time: 3
# (RolloutWorker pid=21952) FPS is currently: 91
# (RolloutWorker pid=5152) total score is -7 at time: 5
# (RolloutWorker pid=5152) FPS is currently: 82
# (RolloutWorker pid=21952) total score is -7 at time: 5
# (RolloutWorker pid=21952) FPS is currently: 80
# (RolloutWorker pid=21952) total score is -9 at time: 7
# (RolloutWorker pid=21952) FPS is currently: 96
# (RolloutWorker pid=5152) total score is -9 at time: 7
# (RolloutWorker pid=5152) FPS is currently: 91
# (RolloutWorker pid=21952) total score is -10 at time: 8
# (RolloutWorker pid=21952) FPS is currently: 81
# (RolloutWorker pid=5152) total score is -10 at time: 8
# (RolloutWorker pid=5152) FPS is currently: 83
# (RolloutWorker pid=21952) total score is -12 at time: 10
# (RolloutWorker pid=21952) FPS is currently: 75
# (RolloutWorker pid=5152) total score is -12 at time: 10
# (RolloutWorker pid=5152) FPS is currently: 74
# (RolloutWorker pid=21952) total score is -14 at time: 12
# (RolloutWorker pid=21952) FPS is currently: 63
# (RolloutWorker pid=5152) total score is -14 at time: 12
# (RolloutWorker pid=5152) FPS is currently: 66
# (RolloutWorker pid=21952) total score is -15 at time: 13
# (RolloutWorker pid=21952) FPS is currently: 81
# (RolloutWorker pid=5152) total score is -15 at time: 13
# (RolloutWorker pid=5152) FPS is currently: 66
# (RolloutWorker pid=21952) total score is -17 at time: 15
# (RolloutWorker pid=21952) FPS is currently: 83
# (RolloutWorker pid=5152) total score is -17 at time: 15
# (RolloutWorker pid=5152) FPS is currently: 85
# (RolloutWorker pid=21952) total score is -19 at time: 17
# (RolloutWorker pid=21952) FPS is currently: 85
# (RolloutWorker pid=5152) total score is -19 at time: 17
# (RolloutWorker pid=5152) FPS is currently: 81
# (RolloutWorker pid=5152) total score is -20 at time: 18
# (RolloutWorker pid=5152) FPS is currently: 96
# (RolloutWorker pid=21952) total score is -20 at time: 18
# (RolloutWorker pid=21952) FPS is currently: 96
# (RolloutWorker pid=21952) total score is -22 at time: 20
# (RolloutWorker pid=21952) FPS is currently: 78
# (RolloutWorker pid=5152) total score is -22 at time: 20
# (RolloutWorker pid=5152) FPS is currently: 75
# (RolloutWorker pid=21952) total score is -24 at time: 22
# (RolloutWorker pid=21952) FPS is currently: 90
# (RolloutWorker pid=5152) total score is -24 at time: 22
# (RolloutWorker pid=5152) FPS is currently: 88
# (RolloutWorker pid=5152) total score is -25 at time: 23
# (RolloutWorker pid=5152) FPS is currently: 88
# (RolloutWorker pid=21952) total score is -25 at time: 23
# (RolloutWorker pid=21952) FPS is currently: 83
# 2022-09-27 21:47:39,567	ERROR algorithm.py:2173 -- Error in training or evaluation attempt! Trying to recover.
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\algorithms\algorithm.py", line 2373, in _run_one_training_iteration
#     results = self.training_step()
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\algorithms\ppo\ppo.py", line 407, in training_step
#     train_batch = synchronous_parallel_sample(
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\execution\rollout_ops.py", line 100, in synchronous_parallel_sample
#     sample_batches = ray.get(
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\worker.py", line 2275, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RayOutOfMemoryError): ray::RolloutWorker.sample() (pid=21952, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x00000217CC07CFA0>)
#   File "python\ray\_raylet.pyx", line 620, in ray._raylet.execute_task
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
#     raise RayOutOfMemoryError(
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-BKAPO4O is used (7.37 / 7.73 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 21952	0.79GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 5152	0.79GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 33124	0.37GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe -m ipykernel_launcher -f C:\Users\Tim\AppData\Roaming\j
# 29420	0.32GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=gpu-process --gpu-preferences=UA
# 17236	0.19GiB	C:\Users\Tim\AppData\Local\Microsoft\OneDrive\OneDrive.exe /background
# 25220	0.17GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
# 18160	0.16GiB	C:\Program Files\WindowsApps\Microsoft.Windows.Photos_2022.30070.26007.0_x64__8wekyb3d8bbwe\Microsof
# 396	0.11GiB	C:\WINDOWS\Explorer.EXE
# 29872	0.11GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
# 28092	0.11GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --no-startup-window /prefetch:5
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---
# 2022-09-27 21:47:41,262	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::RolloutWorker.sample_with_count() (pid=21952, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x00000217CC07CFA0>)
#   File "python\ray\_raylet.pyx", line 620, in ray._raylet.execute_task
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
#     raise RayOutOfMemoryError(
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-BKAPO4O is used (7.37 / 7.73 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 21952	0.79GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 5152	0.79GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 33124	0.37GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe -m ipykernel_launcher -f C:\Users\Tim\AppData\Roaming\j
# 29420	0.3GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=gpu-process --gpu-preferences=UA
# 17236	0.19GiB	C:\Users\Tim\AppData\Local\Microsoft\OneDrive\OneDrive.exe /background
# 25220	0.17GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
# 18160	0.16GiB	C:\Program Files\WindowsApps\Microsoft.Windows.Photos_2022.30070.26007.0_x64__8wekyb3d8bbwe\Microsof
# 396	0.11GiB	C:\WINDOWS\Explorer.EXE
# 28092	0.11GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --no-startup-window /prefetch:5
# 29872	0.11GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---
# 2022-09-27 21:47:41,261	ERROR worker_set.py:728 -- Worker 1 is faulty.
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\algorithms\algorithm.py", line 2373, in _run_one_training_iteration
#     results = self.training_step()
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\algorithms\ppo\ppo.py", line 407, in training_step
#     train_batch = synchronous_parallel_sample(
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\execution\rollout_ops.py", line 100, in synchronous_parallel_sample
#     sample_batches = ray.get(
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\worker.py", line 2275, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RayOutOfMemoryError): ray::RolloutWorker.sample() (pid=21952, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x00000217CC07CFA0>)
#   File "python\ray\_raylet.pyx", line 620, in ray._raylet.execute_task
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
#     raise RayOutOfMemoryError(
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-BKAPO4O is used (7.37 / 7.73 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 21952	0.79GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 5152	0.79GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 33124	0.37GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe -m ipykernel_launcher -f C:\Users\Tim\AppData\Roaming\j
# 29420	0.32GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=gpu-process --gpu-preferences=UA
# 17236	0.19GiB	C:\Users\Tim\AppData\Local\Microsoft\OneDrive\OneDrive.exe /background
# 25220	0.17GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
# 18160	0.16GiB	C:\Program Files\WindowsApps\Microsoft.Windows.Photos_2022.30070.26007.0_x64__8wekyb3d8bbwe\Microsof
# 396	0.11GiB	C:\WINDOWS\Explorer.EXE
# 29872	0.11GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
# 28092	0.11GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --no-startup-window /prefetch:5
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\evaluation\worker_set.py", line 725, in _worker_health_check
#     ray.get(obj_ref)
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\worker.py", line 2275, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RayOutOfMemoryError): ray::RolloutWorker.sample_with_count() (pid=21952, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x00000217CC07CFA0>)
#   File "python\ray\_raylet.pyx", line 620, in ray._raylet.execute_task
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
#     raise RayOutOfMemoryError(
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-BKAPO4O is used (7.37 / 7.73 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 21952	0.79GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 5152	0.79GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 33124	0.37GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe -m ipykernel_launcher -f C:\Users\Tim\AppData\Roaming\j
# 29420	0.3GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=gpu-process --gpu-preferences=UA
# 17236	0.19GiB	C:\Users\Tim\AppData\Local\Microsoft\OneDrive\OneDrive.exe /background
# 25220	0.17GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
# 18160	0.16GiB	C:\Program Files\WindowsApps\Microsoft.Windows.Photos_2022.30070.26007.0_x64__8wekyb3d8bbwe\Microsof
# 396	0.11GiB	C:\WINDOWS\Explorer.EXE
# 28092	0.11GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --no-startup-window /prefetch:5
# 29872	0.11GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---
# 2022-09-27 21:47:41,286	ERROR worker_set.py:728 -- Worker 2 is faulty.
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\algorithms\algorithm.py", line 2373, in _run_one_training_iteration
#     results = self.training_step()
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\algorithms\ppo\ppo.py", line 407, in training_step
#     train_batch = synchronous_parallel_sample(
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\execution\rollout_ops.py", line 100, in synchronous_parallel_sample
#     sample_batches = ray.get(
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\worker.py", line 2275, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RayOutOfMemoryError): ray::RolloutWorker.sample() (pid=21952, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x00000217CC07CFA0>)
#   File "python\ray\_raylet.pyx", line 620, in ray._raylet.execute_task
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
#     raise RayOutOfMemoryError(
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-BKAPO4O is used (7.37 / 7.73 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 21952	0.79GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 5152	0.79GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 33124	0.37GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe -m ipykernel_launcher -f C:\Users\Tim\AppData\Roaming\j
# 29420	0.32GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=gpu-process --gpu-preferences=UA
# 17236	0.19GiB	C:\Users\Tim\AppData\Local\Microsoft\OneDrive\OneDrive.exe /background
# 25220	0.17GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
# 18160	0.16GiB	C:\Program Files\WindowsApps\Microsoft.Windows.Photos_2022.30070.26007.0_x64__8wekyb3d8bbwe\Microsof
# 396	0.11GiB	C:\WINDOWS\Explorer.EXE
# 29872	0.11GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
# 28092	0.11GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --no-startup-window /prefetch:5
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\evaluation\worker_set.py", line 725, in _worker_health_check
#     ray.get(obj_ref)
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\worker.py", line 2275, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RayOutOfMemoryError): ray::RolloutWorker.sample_with_count() (pid=5152, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000019F7284CFA0>)
#   File "python\ray\_raylet.pyx", line 620, in ray._raylet.execute_task
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
#     raise RayOutOfMemoryError(
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-BKAPO4O is used (7.37 / 7.73 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 21952	0.79GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 5152	0.79GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 33124	0.37GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe -m ipykernel_launcher -f C:\Users\Tim\AppData\Roaming\j
# 29420	0.3GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=gpu-process --gpu-preferences=UA
# 17236	0.19GiB	C:\Users\Tim\AppData\Local\Microsoft\OneDrive\OneDrive.exe /background
# 25220	0.17GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
# 18160	0.16GiB	C:\Program Files\WindowsApps\Microsoft.Windows.Photos_2022.30070.26007.0_x64__8wekyb3d8bbwe\Microsof
# 396	0.11GiB	C:\WINDOWS\Explorer.EXE
# 28092	0.11GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --no-startup-window /prefetch:5
# 29872	0.11GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---
# 2022-09-27 21:47:41,291	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::RolloutWorker.sample_with_count() (pid=5152, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000019F7284CFA0>)
#   File "python\ray\_raylet.pyx", line 620, in ray._raylet.execute_task
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
#     raise RayOutOfMemoryError(
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-BKAPO4O is used (7.37 / 7.73 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 21952	0.79GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 5152	0.79GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 33124	0.37GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe -m ipykernel_launcher -f C:\Users\Tim\AppData\Roaming\j
# 29420	0.3GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=gpu-process --gpu-preferences=UA
# 17236	0.19GiB	C:\Users\Tim\AppData\Local\Microsoft\OneDrive\OneDrive.exe /background
# 25220	0.17GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
# 18160	0.16GiB	C:\Program Files\WindowsApps\Microsoft.Windows.Photos_2022.30070.26007.0_x64__8wekyb3d8bbwe\Microsof
# 396	0.11GiB	C:\WINDOWS\Explorer.EXE
# 28092	0.11GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --no-startup-window /prefetch:5
# 29872	0.11GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---
# 2022-09-27 21:47:41,404	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::RolloutWorker.sample() (pid=5152, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000019F7284CFA0>)
#   File "python\ray\_raylet.pyx", line 620, in ray._raylet.execute_task
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
#     raise RayOutOfMemoryError(
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-BKAPO4O is used (7.37 / 7.73 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 21952	0.79GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 5152	0.79GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 33124	0.37GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe -m ipykernel_launcher -f C:\Users\Tim\AppData\Roaming\j
# 29420	0.32GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=gpu-process --gpu-preferences=UA
# 17236	0.19GiB	C:\Users\Tim\AppData\Local\Microsoft\OneDrive\OneDrive.exe /background
# 25220	0.17GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
# 18160	0.16GiB	C:\Program Files\WindowsApps\Microsoft.Windows.Photos_2022.30070.26007.0_x64__8wekyb3d8bbwe\Microsof
# 396	0.11GiB	C:\WINDOWS\Explorer.EXE
# 29872	0.11GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
# 28092	0.11GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --no-startup-window /prefetch:5
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---
# (pid=940) Windows fatal exception: code 0xc0000139
# (pid=940)
# (pid=27112) Windows fatal exception: code 0xc0000139
# (pid=27112)
# (pid=940) C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\tensorflow_probability\python\__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=940)   if (distutils.version.LooseVersion(tf.__version__) <
# (pid=27112) C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\tensorflow_probability\python\__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=27112)   if (distutils.version.LooseVersion(tf.__version__) <
# (RolloutWorker pid=27112) 2022-09-27 21:47:55,629	WARNING env.py:142 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=940) resetting in wrapper
# (RolloutWorker pid=940) Torch was not collected this episode...
# (RolloutWorker pid=940) [False]
# (RolloutWorker pid=27112) resetting in wrapper
# (RolloutWorker pid=27112) Torch was not collected this episode...
# (RolloutWorker pid=27112) [False]
# (RolloutWorker pid=940) resetting
# (RolloutWorker pid=27112) resetting
# (RolloutWorker pid=27112) resetting in wrapper
# (RolloutWorker pid=27112) Torch was not collected this episode...
# (RolloutWorker pid=27112) [False, 0]
# (RolloutWorker pid=27112) resetting
# (RolloutWorker pid=940) resetting in wrapper
# (RolloutWorker pid=940) Torch was not collected this episode...
# (RolloutWorker pid=940) [False, 0]
# (RolloutWorker pid=940) resetting
# (RolloutWorker pid=27112) Game completed with a score of: 99 at time: 0
# (RolloutWorker pid=27112) done is True, resetting environment in wrapper.
# (RolloutWorker pid=27112) steps taken: 29
# (RolloutWorker pid=27112) resetting in wrapper
# (RolloutWorker pid=27112) Torch was not collected this episode...
# (RolloutWorker pid=27112) [False, 0, 0]
# (RolloutWorker pid=27112) resetting
# (RolloutWorker pid=940) total score is -2 at time: 2
# (RolloutWorker pid=940) FPS is currently: 67
# (RolloutWorker pid=27112) resetting in wrapper
# (RolloutWorker pid=27112) Torch was not collected this episode...
# (RolloutWorker pid=27112) [False, 0, 0, False]
# (RolloutWorker pid=27112) resetting
# (RolloutWorker pid=940) total score is -3 at time: 3
# (RolloutWorker pid=940) FPS is currently: 92
# (RolloutWorker pid=27112) total score is -2 at time: 2
# (RolloutWorker pid=27112) FPS is currently: 80
# (RolloutWorker pid=27112) total score is -3 at time: 3
# (RolloutWorker pid=27112) FPS is currently: 97
# (RolloutWorker pid=940) total score is -5 at time: 5
# (RolloutWorker pid=940) FPS is currently: 62
# (RolloutWorker pid=27112) total score is -5 at time: 5
# (RolloutWorker pid=27112) FPS is currently: 95
# (RolloutWorker pid=940) total score is -7 at time: 7
# (RolloutWorker pid=940) FPS is currently: 64
# (RolloutWorker pid=27112) total score is -7 at time: 7
# (RolloutWorker pid=27112) FPS is currently: 68
# (RolloutWorker pid=940) total score is -8 at time: 8
# (RolloutWorker pid=940) FPS is currently: 70
# (RolloutWorker pid=27112) total score is -8 at time: 8
# (RolloutWorker pid=27112) FPS is currently: 91
# (RolloutWorker pid=940) total score is -10 at time: 10
# (RolloutWorker pid=940) FPS is currently: 54
# (RolloutWorker pid=27112) total score is -10 at time: 10
# (RolloutWorker pid=27112) FPS is currently: 94
# (RolloutWorker pid=27112) total score is -12 at time: 12
# (RolloutWorker pid=27112) FPS is currently: 94
# (RolloutWorker pid=940) total score is -12 at time: 12
# (RolloutWorker pid=940) FPS is currently: 55
# (RolloutWorker pid=940) total score is -13 at time: 13
# (RolloutWorker pid=940) FPS is currently: 63
# 2022-09-27 21:48:30,411	ERROR algorithm.py:2173 -- Error in training or evaluation attempt! Trying to recover.
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\algorithms\algorithm.py", line 2373, in _run_one_training_iteration
#     results = self.training_step()
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\algorithms\ppo\ppo.py", line 407, in training_step
#     train_batch = synchronous_parallel_sample(
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\execution\rollout_ops.py", line 100, in synchronous_parallel_sample
#     sample_batches = ray.get(
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\worker.py", line 2275, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RayOutOfMemoryError): ray::RolloutWorker.sample() (pid=27112, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000019CFF12CFA0>)
#   File "python\ray\_raylet.pyx", line 620, in ray._raylet.execute_task
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
#     raise RayOutOfMemoryError(
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-BKAPO4O is used (7.35 / 7.73 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 27112	0.77GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 17236	0.44GiB	C:\Users\Tim\AppData\Local\Microsoft\OneDrive\OneDrive.exe /background
# 940	0.41GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 29420	0.29GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=gpu-process --gpu-preferences=UA
# 18160	0.22GiB	C:\Program Files\WindowsApps\Microsoft.Windows.Photos_2022.30070.26007.0_x64__8wekyb3d8bbwe\Microsof
# 33124	0.21GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe -m ipykernel_launcher -f C:\Users\Tim\AppData\Roaming\j
# 25220	0.19GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
# 28092	0.12GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --no-startup-window /prefetch:5
# 16228	0.09GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
# 396	0.08GiB	C:\WINDOWS\Explorer.EXE
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---
# (RolloutWorker pid=27112) total score is -13 at time: 13
# (RolloutWorker pid=27112) FPS is currently: 78
# (RolloutWorker pid=27112) total score is -15 at time: 15
# (RolloutWorker pid=27112) FPS is currently: 82
# (RolloutWorker pid=940) total score is -15 at time: 15
# (RolloutWorker pid=940) FPS is currently: 57
# 2022-09-27 21:48:36,096	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::RolloutWorker.sample() (pid=940, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000015EF643CF40>)
#   File "python\ray\_raylet.pyx", line 620, in ray._raylet.execute_task
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
#     raise RayOutOfMemoryError(
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-BKAPO4O is used (7.35 / 7.73 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 27112	0.77GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 17236	0.44GiB	C:\Users\Tim\AppData\Local\Microsoft\OneDrive\OneDrive.exe /background
# 940	0.41GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 29420	0.29GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=gpu-process --gpu-preferences=UA
# 18160	0.22GiB	C:\Program Files\WindowsApps\Microsoft.Windows.Photos_2022.30070.26007.0_x64__8wekyb3d8bbwe\Microsof
# 33124	0.21GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe -m ipykernel_launcher -f C:\Users\Tim\AppData\Roaming\j
# 25220	0.19GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
# 28092	0.12GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --no-startup-window /prefetch:5
# 16228	0.09GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
# 396	0.08GiB	C:\WINDOWS\Explorer.EXE
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---
# (RolloutWorker pid=940) total score is -17 at time: 17
# (RolloutWorker pid=940) FPS is currently: 72
# (RolloutWorker pid=27112) total score is -17 at time: 17
# (RolloutWorker pid=27112) FPS is currently: 102
# (RolloutWorker pid=27112) total score is -18 at time: 18
# (RolloutWorker pid=27112) FPS is currently: 89
# (RolloutWorker pid=940) total score is -18 at time: 18
# (RolloutWorker pid=940) FPS is currently: 65
# (RolloutWorker pid=940) total score is -20 at time: 20
# (RolloutWorker pid=940) FPS is currently: 67
# (RolloutWorker pid=27112) total score is -20 at time: 20
# (RolloutWorker pid=27112) FPS is currently: 72
# (RolloutWorker pid=27112) total score is -22 at time: 22
# (RolloutWorker pid=27112) FPS is currently: 77
# (RolloutWorker pid=940) total score is -22 at time: 22
# (RolloutWorker pid=940) FPS is currently: 55
# (RolloutWorker pid=940) total score is -23 at time: 23
# (RolloutWorker pid=940) FPS is currently: 68
# (RolloutWorker pid=27112) total score is -23 at time: 23
# (RolloutWorker pid=27112) FPS is currently: 71
# (RolloutWorker pid=940) total score is -25 at time: 25
# (RolloutWorker pid=940) FPS is currently: 69
# (RolloutWorker pid=27112) total score is -25 at time: 25
# (RolloutWorker pid=27112) FPS is currently: 68
# (RolloutWorker pid=940) total score is -27 at time: 27
# (RolloutWorker pid=940) FPS is currently: 56
# (RolloutWorker pid=27112) total score is -27 at time: 27
# (RolloutWorker pid=27112) FPS is currently: 72
# (RolloutWorker pid=940) total score is -28 at time: 28
# (RolloutWorker pid=940) FPS is currently: 75
# (RolloutWorker pid=27112) total score is -28 at time: 28
# (RolloutWorker pid=27112) FPS is currently: 74
# (RolloutWorker pid=940) total score is -30 at time: 30
# (RolloutWorker pid=940) FPS is currently: 62
# (RolloutWorker pid=27112) total score is -30 at time: 30
# (RolloutWorker pid=27112) FPS is currently: 67
# (RolloutWorker pid=940) total score is -32 at time: 32
# (RolloutWorker pid=940) FPS is currently: 66
# (RolloutWorker pid=27112) total score is -32 at time: 32
# (RolloutWorker pid=27112) FPS is currently: 79
# (RolloutWorker pid=940) total score is -33 at time: 33
# (RolloutWorker pid=940) FPS is currently: 68
# (RolloutWorker pid=27112) total score is -33 at time: 33
# (RolloutWorker pid=27112) FPS is currently: 88
# (RolloutWorker pid=940) total score is -35 at time: 35
# (RolloutWorker pid=940) FPS is currently: 76
# (RolloutWorker pid=27112) total score is -35 at time: 35
# (RolloutWorker pid=27112) FPS is currently: 86
# (RolloutWorker pid=940) total score is -37 at time: 37
# (RolloutWorker pid=940) FPS is currently: 68
# 2022-09-27 21:49:16,118	ERROR algorithm.py:2173 -- Error in training or evaluation attempt! Trying to recover.
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\algorithms\algorithm.py", line 2373, in _run_one_training_iteration
#     results = self.training_step()
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\algorithms\ppo\ppo.py", line 407, in training_step
#     train_batch = synchronous_parallel_sample(
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\execution\rollout_ops.py", line 100, in synchronous_parallel_sample
#     sample_batches = ray.get(
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\worker.py", line 2275, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RayOutOfMemoryError): ray::RolloutWorker.sample() (pid=27112, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000019CFF12CFA0>)
#   File "python\ray\_raylet.pyx", line 620, in ray._raylet.execute_task
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
#     raise RayOutOfMemoryError(
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-BKAPO4O is used (7.37 / 7.73 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 27112	0.75GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 17236	0.46GiB	C:\Users\Tim\AppData\Local\Microsoft\OneDrive\OneDrive.exe /background
# 940	0.41GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 29420	0.28GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=gpu-process --gpu-preferences=UA
# 18160	0.22GiB	C:\Program Files\WindowsApps\Microsoft.Windows.Photos_2022.30070.26007.0_x64__8wekyb3d8bbwe\Microsof
# 33124	0.21GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe -m ipykernel_launcher -f C:\Users\Tim\AppData\Roaming\j
# 25220	0.19GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
# 28092	0.12GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --no-startup-window /prefetch:5
# 9772	0.11GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --instant-process --dis
# 16228	0.09GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---
# (RolloutWorker pid=27112) total score is -37 at time: 37
# (RolloutWorker pid=27112) FPS is currently: 100
# (RolloutWorker pid=27112) total score is -38 at time: 38
# (RolloutWorker pid=27112) FPS is currently: 71
# (RolloutWorker pid=940) total score is -38 at time: 38
# (RolloutWorker pid=940) FPS is currently: 64
# 2022-09-27 21:49:21,486	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::RolloutWorker.sample() (pid=940, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000015EF643CF40>)
#   File "python\ray\_raylet.pyx", line 620, in ray._raylet.execute_task
#   File "C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
#     raise RayOutOfMemoryError(
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-BKAPO4O is used (7.37 / 7.73 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 27112	0.75GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 17236	0.46GiB	C:\Users\Tim\AppData\Local\Microsoft\OneDrive\OneDrive.exe /background
# 940	0.41GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray
# 29420	0.28GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=gpu-process --gpu-preferences=UA
# 18160	0.22GiB	C:\Program Files\WindowsApps\Microsoft.Windows.Photos_2022.30070.26007.0_x64__8wekyb3d8bbwe\Microsof
# 33124	0.21GiB	C:\Users\Tim\Anaconda3\envs\rllib\python.exe -m ipykernel_launcher -f C:\Users\Tim\AppData\Roaming\j
# 25220	0.19GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
# 28092	0.12GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --no-startup-window /prefetch:5
# 9772	0.11GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --instant-process --dis
# 16228	0.09GiB	C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe --type=renderer --display-capture-permi
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---
# (RolloutWorker pid=940) total score is -40 at time: 40
# (RolloutWorker pid=940) FPS is currently: 67
# (RolloutWorker pid=27112) total score is -40 at time: 40
# (RolloutWorker pid=27112) FPS is currently: 93
# (RolloutWorker pid=940) total score is -42 at time: 42
# (RolloutWorker pid=940) FPS is currently: 90
# (RolloutWorker pid=27112) total score is -42 at time: 42
# (RolloutWorker pid=27112) FPS is currently: 88
# (RolloutWorker pid=940) total score is -43 at time: 43
# (RolloutWorker pid=940) FPS is currently: 59
# (RolloutWorker pid=27112) total score is -43 at time: 43
# (RolloutWorker pid=27112) FPS is currently: 80
# (RolloutWorker pid=940) total score is -45 at time: 45
# (RolloutWorker pid=940) FPS is currently: 72
# (RolloutWorker pid=27112) total score is -45 at time: 45
# (RolloutWorker pid=27112) FPS is currently: 81
# (RolloutWorker pid=940) total score is -47 at time: 47
# (RolloutWorker pid=940) FPS is currently: 62
# (RolloutWorker pid=27112) total score is -47 at time: 47
# (RolloutWorker pid=27112) FPS is currently: 86
# (RolloutWorker pid=940) total score is -48 at time: 48
# (RolloutWorker pid=940) FPS is currently: 61
# (RolloutWorker pid=27112) total score is -48 at time: 48
# (RolloutWorker pid=27112) FPS is currently: 86
# (RolloutWorker pid=940) total score is -50 at time: 50
# (RolloutWorker pid=940) FPS is currently: 61
# (RolloutWorker pid=27112) total score is -50 at time: 50
# (RolloutWorker pid=27112) FPS is currently: 94
# (RolloutWorker pid=940) total score is -52 at time: 52
# (RolloutWorker pid=940) FPS is currently: 64
# (RolloutWorker pid=27112) total score is -52 at time: 52
# (RolloutWorker pid=27112) FPS is currently: 85
# (RolloutWorker pid=940) total score is -53 at time: 53
# (RolloutWorker pid=940) FPS is currently: 69
# (RolloutWorker pid=27112) total score is -53 at time: 53
# (RolloutWorker pid=27112) FPS is currently: 85
# (RolloutWorker pid=940) total score is -55 at time: 55
# (RolloutWorker pid=940) FPS is currently: 72
# (RolloutWorker pid=27112) total score is -55 at time: 55
# (RolloutWorker pid=27112) FPS is currently: 79
# (RolloutWorker pid=940) total score is -57 at time: 57
# (RolloutWorker pid=940) FPS is currently: 69
# (RolloutWorker pid=27112) total score is -57 at time: 57
# (RolloutWorker pid=27112) FPS is currently: 93
# (RolloutWorker pid=940) total score is -58 at time: 58
# (RolloutWorker pid=940) FPS is currently: 69
# (RolloutWorker pid=27112) total score is -58 at time: 58
# (RolloutWorker pid=27112) FPS is currently: 94
# (RolloutWorker pid=940) total score is -60 at time: 60
# (RolloutWorker pid=940) FPS is currently: 63
# (RolloutWorker pid=27112) total score is -60 at time: 60
# (RolloutWorker pid=27112) FPS is currently: 83
# (RolloutWorker pid=940) total score is -62 at time: 62
# (RolloutWorker pid=940) FPS is currently: 68
# (RolloutWorker pid=27112) total score is -62 at time: 62
# (RolloutWorker pid=27112) FPS is currently: 74
# (RolloutWorker pid=940) total score is -63 at time: 63
# ...
# (RolloutWorker pid=27112) FPS is currently: 106
# (RolloutWorker pid=940) total score is -134 at time: 113
# (RolloutWorker pid=940) FPS is currently: 100
# (RolloutWorker pid=27112) total score is -16 at time: 12
# (RolloutWorker pid=27112) FPS is currently: 96
# (RolloutWorker pid=940) total score is -136 at time: 115
# (RolloutWorker pid=940) FPS is currently: 82
# (RolloutWorker pid=27112) total score is -17 at time: 13
# (RolloutWorker pid=27112) FPS is currently: 88
# (RolloutWorker pid=940) total score is -138 at time: 117
# (RolloutWorker pid=940) FPS is currently: 82
# (RolloutWorker pid=27112) total score is -19 at time: 15
# (RolloutWorker pid=27112) FPS is currently: 89
# (RolloutWorker pid=940) total score is -139 at time: 118
# (RolloutWorker pid=940) FPS is currently: 74
# (RolloutWorker pid=27112) total score is -21 at time: 17
# (RolloutWorker pid=27112) FPS is currently: 87
# (RolloutWorker pid=940) total score is -141 at time: 120
# (RolloutWorker pid=940) FPS is currently: 84
# (RolloutWorker pid=27112) total score is -24 at time: 18
# (RolloutWorker pid=27112) FPS is currently: 93
# (RolloutWorker pid=940) total score is -143 at time: 122
# (RolloutWorker pid=940) FPS is currently: 91
# (RolloutWorker pid=27112) total score is -27 at time: 20
# (RolloutWorker pid=27112) FPS is currently: 99
# (RolloutWorker pid=940) total score is -145 at time: 123
# (RolloutWorker pid=940) FPS is currently: 81
# (RolloutWorker pid=27112) total score is -30 at time: 22
# (RolloutWorker pid=27112) FPS is currently: 85
# (RolloutWorker pid=940) total score is -147 at time: 125
# (RolloutWorker pid=940) FPS is currently: 95
# (RolloutWorker pid=27112) total score is -31 at time: 23
# (RolloutWorker pid=27112) FPS is currently: 87
# (RolloutWorker pid=940) total score is -150 at time: 127
# (RolloutWorker pid=940) FPS is currently: 83
# (RolloutWorker pid=27112) total score is -33 at time: 25
# (RolloutWorker pid=27112) FPS is currently: 92
# (RolloutWorker pid=940) total score is -151 at time: 128
# (RolloutWorker pid=940) FPS is currently: 97
# (RolloutWorker pid=27112) total score is -35 at time: 27
# (RolloutWorker pid=27112) FPS is currently: 89
# (RolloutWorker pid=940) total score is -153 at time: 130
# (RolloutWorker pid=940) FPS is currently: 97
# (RolloutWorker pid=27112) total score is -36 at time: 28
# (RolloutWorker pid=27112) FPS is currently: 87
# (RolloutWorker pid=940) total score is -156 at time: 132
# (RolloutWorker pid=940) FPS is currently: 98
# (RolloutWorker pid=27112) total score is -38 at time: 30
# (RolloutWorker pid=27112) FPS is currently: 95
# (RolloutWorker pid=940) total score is -157 at time: 133
# (RolloutWorker pid=940) FPS is currently: 98
# (RolloutWorker pid=27112) total score is -41 at time: 32
# (RolloutWorker pid=27112) FPS is currently: 90
# (RolloutWorker pid=940) total score is -159 at time: 135
# (RolloutWorker pid=940) FPS is currently: 92
# (RolloutWorker pid=27112) total score is -42 at time: 33
# (RolloutWorker pid=27112) FPS is currently: 93
# (RolloutWorker pid=940) total score is -161 at time: 137
# (RolloutWorker pid=940) FPS is currently: 91
# (RolloutWorker pid=27112) total score is -44 at time: 35
# (RolloutWorker pid=27112) FPS is currently: 90
# (RolloutWorker pid=940) total score is -162 at time: 138
# (RolloutWorker pid=940) FPS is currently: 81
# episode reward mean:  -162.44444444444446
# checkpoint saved at C:\Users\Tim/ray_results\PPO_LightEnvWrapper_2022-09-27_21-46-32itz4gpn9\checkpoint_000031
# End of episode  30
# Starting episode  31
# (RolloutWorker pid=27112) total score is -46 at time: 37
# (RolloutWorker pid=27112) FPS is currently: 102
# (RolloutWorker pid=940) total score is -165 at time: 140
# (RolloutWorker pid=940) FPS is currently: 102
# (RolloutWorker pid=27112) total score is -47 at time: 38
# (RolloutWorker pid=27112) FPS is currently: 106
# (RolloutWorker pid=940) total score is -167 at time: 142
# (RolloutWorker pid=940) FPS is currently: 83
# (RolloutWorker pid=27112) total score is -49 at time: 40
# (RolloutWorker pid=27112) FPS is currently: 84
# (RolloutWorker pid=940) total score is -168 at time: 143
# (RolloutWorker pid=940) FPS is currently: 88
# (RolloutWorker pid=27112) total score is -51 at time: 42
# (RolloutWorker pid=27112) FPS is currently: 78
# (RolloutWorker pid=940) total score is -171 at time: 145
# (RolloutWorker pid=940) FPS is currently: 85
# (RolloutWorker pid=27112) total score is -52 at time: 43
# (RolloutWorker pid=27112) FPS is currently: 97
# (RolloutWorker pid=940) total score is -173 at time: 147
# (RolloutWorker pid=940) FPS is currently: 87
# (RolloutWorker pid=27112) total score is -54 at time: 45
# (RolloutWorker pid=27112) FPS is currently: 82
# (RolloutWorker pid=940) total score is -174 at time: 148
# (RolloutWorker pid=940) FPS is currently: 93
# (RolloutWorker pid=27112) total score is -56 at time: 47
# (RolloutWorker pid=27112) FPS is currently: 97
# (RolloutWorker pid=940) total score is -176 at time: 150
# (RolloutWorker pid=940) FPS is currently: 90
# (RolloutWorker pid=27112) total score is -57 at time: 48
# (RolloutWorker pid=27112) FPS is currently: 95
# (RolloutWorker pid=940) total score is -178 at time: 152
# (RolloutWorker pid=940) FPS is currently: 94
# (RolloutWorker pid=27112) total score is -59 at time: 50
# (RolloutWorker pid=27112) FPS is currently: 88
# (RolloutWorker pid=940) total score is -179 at time: 153
# (RolloutWorker pid=940) FPS is currently: 79
# (RolloutWorker pid=27112) total score is -61 at time: 52
# (RolloutWorker pid=27112) FPS is currently: 87
# (RolloutWorker pid=940) total score is -181 at time: 155
# (RolloutWorker pid=940) FPS is currently: 81
# (RolloutWorker pid=27112) total score is -62 at time: 53
# (RolloutWorker pid=27112) FPS is currently: 80
# (RolloutWorker pid=940) total score is -183 at time: 157
# (RolloutWorker pid=940) FPS is currently: 94
# (RolloutWorker pid=27112) total score is -65 at time: 55
# (RolloutWorker pid=27112) FPS is currently: 87
# (RolloutWorker pid=940) total score is -184 at time: 158
# (RolloutWorker pid=940) FPS is currently: 79
# (RolloutWorker pid=27112) total score is -67 at time: 57
# (RolloutWorker pid=27112) FPS is currently: 89
# (RolloutWorker pid=940) total score is -186 at time: 160
# (RolloutWorker pid=940) FPS is currently: 90
# (RolloutWorker pid=27112) total score is -68 at time: 58
# (RolloutWorker pid=27112) FPS is currently: 85
# (RolloutWorker pid=940) total score is -188 at time: 162
# (RolloutWorker pid=940) FPS is currently: 88
# (RolloutWorker pid=27112) total score is -70 at time: 60
# (RolloutWorker pid=27112) FPS is currently: 85
# (RolloutWorker pid=940) total score is -189 at time: 163
# (RolloutWorker pid=940) FPS is currently: 91
# (RolloutWorker pid=27112) total score is -72 at time: 62
# (RolloutWorker pid=27112) FPS is currently: 94
# (RolloutWorker pid=940) total score is -191 at time: 165
# (RolloutWorker pid=940) FPS is currently: 85
# (RolloutWorker pid=27112) total score is -73 at time: 63
# (RolloutWorker pid=27112) FPS is currently: 84
# (RolloutWorker pid=940) total score is -193 at time: 167
# (RolloutWorker pid=940) FPS is currently: 90
# (RolloutWorker pid=27112) total score is -75 at time: 65
# (RolloutWorker pid=27112) FPS is currently: 89
# (RolloutWorker pid=940) total score is -194 at time: 168
# (RolloutWorker pid=940) FPS is currently: 84
# (RolloutWorker pid=27112) total score is -77 at time: 67
# (RolloutWorker pid=27112) FPS is currently: 101
# (RolloutWorker pid=940) total score is -196 at time: 170
# (RolloutWorker pid=940) FPS is currently: 99
# (RolloutWorker pid=27112) total score is -79 at time: 68
# (RolloutWorker pid=27112) FPS is currently: 85
# (RolloutWorker pid=940) total score is -198 at time: 172
# (RolloutWorker pid=940) FPS is currently: 96
# C:\Users\Tim\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\policy\dynamic_tf_policy_v2.py:517: DeprecationWarning: invalid escape sequence \d
#   mo = re.match("state_in_(\d+)", view_col)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [2], line 31
#      29 print("Starting episode ", episode)
#      30 # Perform one iteration of training the policy with PPO
# ---> 31 result = trainer.train()
#      32 #print(pretty_print(result))
#      33 print("episode reward mean: ", result['episode_reward_mean'])
#
# File ~\Anaconda3\envs\rllib\lib\site-packages\ray\tune\trainable\trainable.py:347, in Trainable.train(self)
#     345     self._warmup_time = time.time() - self._start_time
#     346 start = time.time()
# --> 347 result = self.step()
#     348 assert isinstance(result, dict), "step() needs to return a dict."
#     350 # We do not modify internal state nor update this result if duplicate.
#
# File ~\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\algorithms\algorithm.py:661, in Algorithm.step(self)
#     653     (
#     654         results,
#     655         train_iter_ctx,
#     656     ) = self._run_one_training_iteration_and_evaluation_in_parallel()
#     657 # - No evaluation necessary, just run the next training iteration.
#     658 # - We have to evaluate in this training iteration, but no parallelism ->
#     659 #   evaluate after the training iteration is entirely done.
#     660 else:
# --> 661     results, train_iter_ctx = self._run_one_training_iteration()
#     663 # Sequential: Train (already done above), then evaluate.
#     664 if evaluate_this_iter and not self.config["evaluation_parallel_to_training"]:
#
# File ~\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\algorithms\algorithm.py:2373, in Algorithm._run_one_training_iteration(self)
#    2371 with self._timers[TRAINING_ITERATION_TIMER]:
#    2372     if self.config["_disable_execution_plan_api"]:
# -> 2373         results = self.training_step()
#    2374     else:
#    2375         results = next(self.train_exec_impl)
#
# File ~\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\algorithms\ppo\ppo.py:420, in PPO.training_step(self)
#     418     train_results = train_one_step(self, train_batch)
#     419 else:
# --> 420     train_results = multi_gpu_train_one_step(self, train_batch)
#     422 global_vars = {
#     423     "timestep": self._counters[NUM_AGENT_STEPS_SAMPLED],
#     424 }
#     426 # Update weights - after learning on the local worker - on all remote
#     427 # workers.
#
# File ~\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\execution\train_ops.py:176, in multi_gpu_train_one_step(algorithm, train_batch)
#     171         permutation = np.random.permutation(num_batches)
#     172         for batch_index in range(num_batches):
#     173             # Learn on the pre-loaded data in the buffer.
#     174             # Note: For minibatch SGD, the data is an offset into
#     175             # the pre-loaded entire train batch.
# --> 176             results = policy.learn_on_loaded_batch(
#     177                 permutation[batch_index] * per_device_batch_size, buffer_index=0
#     178             )
#     180             learner_info_builder.add_learn_on_batch_results(results, policy_id)
#     182 # Tower reduce and finalize results.
#
# File ~\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\policy\dynamic_tf_policy_v2.py:1029, in DynamicTFPolicyV2.learn_on_loaded_batch(self, offset, buffer_index)
#    1025     else:
#    1026         sliced_batch = self._loaded_single_cpu_batch.slice(
#    1027             start=offset, end=offset + batch_size
#    1028         )
# -> 1029     return self.learn_on_batch(sliced_batch)
#    1031 return self.multi_gpu_tower_stacks[buffer_index].optimize(
#    1032     self.get_session(), offset
#    1033 )
#
# File ~\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\policy\tf_policy.py:436, in TFPolicy.learn_on_batch(self, postprocessed_batch)
#     431 self.callbacks.on_learn_on_batch(
#     432     policy=self, train_batch=postprocessed_batch, result=learn_stats
#     433 )
#     435 fetches = self._build_learn_on_batch(builder, postprocessed_batch)
# --> 436 stats = builder.get(fetches)
#     437 stats.update(
#     438     {
#     439         "custom_metrics": learn_stats,
#     440         NUM_AGENT_STEPS_TRAINED: postprocessed_batch.count,
#     441     }
#     442 )
#     443 return stats
#
# File ~\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\utils\tf_run_builder.py:42, in _TFRunBuilder.get(self, to_fetch)
#      40 if self._executed is None:
#      41     try:
# ---> 42         self._executed = _run_timeline(
#      43             self.session,
#      44             self.fetches,
#      45             self.debug_name,
#      46             self.feed_dict,
#      47             os.environ.get("TF_TIMELINE_DIR"),
#      48         )
#      49     except Exception as e:
#      50         logger.exception(
#      51             "Error fetching: {}, feed_dict={}".format(
#      52                 self.fetches, self.feed_dict
#      53             )
#      54         )
#
# File ~\Anaconda3\envs\rllib\lib\site-packages\ray\rllib\utils\tf_run_builder.py:102, in _run_timeline(sess, ops, debug_name, feed_dict, timeline_dir)
#      97     if log_once("tf_timeline"):
#      98         logger.info(
#      99             "Executing TF run without tracing. To dump TF timeline traces "
#     100             "to disk, set the TF_TIMELINE_DIR environment variable."
#     101         )
# --> 102     fetches = sess.run(ops, feed_dict=feed_dict)
#     103 return fetches
#
# File ~\Anaconda3\envs\rllib\lib\site-packages\tensorflow\python\client\session.py:968, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     965 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     967 try:
# --> 968   result = self._run(None, fetches, feed_dict, options_ptr,
#     969                      run_metadata_ptr)
#     970   if run_metadata:
#     971     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File ~\Anaconda3\envs\rllib\lib\site-packages\tensorflow\python\client\session.py:1191, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1188 # We only want to really perform the run if fetches or targets are provided,
#    1189 # or if the call is a partial run that specifies feeds.
#    1190 if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1191   results = self._do_run(handle, final_targets, final_fetches,
#    1192                          feed_dict_tensor, options, run_metadata)
#    1193 else:
#    1194   results = []
#
# File ~\Anaconda3\envs\rllib\lib\site-packages\tensorflow\python\client\session.py:1371, in BaseSession._do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1368   return self._call_tf_sessionprun(handle, feed_dict, fetch_list)
#    1370 if handle is None:
# -> 1371   return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1372                        run_metadata)
#    1373 else:
#    1374   return self._do_call(_prun_fn, handle, feeds, fetches)
#
# File ~\Anaconda3\envs\rllib\lib\site-packages\tensorflow\python\client\session.py:1378, in BaseSession._do_call(self, fn, *args)
#    1376 def _do_call(self, fn, *args):
#    1377   try:
# -> 1378     return fn(*args)
#    1379   except errors.OpError as e:
#    1380     message = compat.as_text(e.message)
#
# File ~\Anaconda3\envs\rllib\lib\site-packages\tensorflow\python\client\session.py:1361, in BaseSession._do_run.<locals>._run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1358 def _run_fn(feed_dict, fetch_list, target_list, options, run_metadata):
#    1359   # Ensure any changes to the graph are reflected in the runtime.
#    1360   self._extend_graph()
# -> 1361   return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1362                                   target_list, run_metadata)
#
# File ~\Anaconda3\envs\rllib\lib\site-packages\tensorflow\python\client\session.py:1454, in BaseSession._call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1452 def _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list,
#    1453                         run_metadata):
# -> 1454   return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1455                                           fetch_list, target_list,
#    1456                                           run_metadata)
#
# KeyboardInterrupt:
